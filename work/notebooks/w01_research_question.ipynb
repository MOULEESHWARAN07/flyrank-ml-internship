# %% [markdown]
# <a href="https://colab.research.google.com/github/MOULEESHWARAN07/flyrank-ml-internship/blob/main/work/notebooks/w01_research_question.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # ML-02 — Research Question and Provisional Lane
#
# [![Open In Colab](https://colab.research.google.com/assets/colab-badge.svg)](https://colab.research.google.com/github/MOULEESHWARAN07/flyrank-ml-internship/blob/main/work/notebooks/w01_research_question.ipynb?flush_cache=true)
#
# This skeleton is yours to fill. Work the sections **in order** — each one has a one-line hint. Simple words, honest numbers.
#
# > Working with an AI assistant? Tell it to read `skills/README.md` first and load the one skill this assignment names on its card.

# %% [markdown]
# ## 1. My lane (or freestyle) and why
#
# *Name your lane — or say 'freestyle' and describe your own question. One short paragraph: why this one?*

# %% [markdown]
# ## My Lane
#
# **Lane:** decline_recovery
#
# I chose the **decline_recovery** lane because it focuses on identifying webpages that are likely to recover after a decline in search performance. This can help SEO teams prioritize pages for optimization, improving resource allocation and increasing the chances of recovering valuable organic traffic. I find this problem interesting because it combines business decision-making with machine learning.

# %% [markdown]
# ## 2. The question: decision, action, cost of a wrong call
#
# *What decision does your work improve? Who acts on it? What does a wrong recommendation cost?*

# %% [markdown]
# ## Research Question
#
# **Decision:** Which webpages should be prioritized for optimization because they are most likely to recover from a ranking decline?
#
# **Who acts on it?** The SEO team and content managers.
#
# **Action:** Refresh or improve the selected webpages by updating content, keywords, and technical SEO.
#
# **Cost of a wrong recommendation:** Recommending the wrong pages wastes time and optimization effort, while missing valuable pages may result in lost traffic and business opportunities.

# %% [markdown]
# ## 3. Quick look at the data (2-3 real numbers)
#
# *Load the starter CSV below and show 2-3 real numbers that make your lane look worth the next 7 weeks.*

# %%
import os
import subprocess
import sys

REPO_URL = "https://github.com/MOULEESHWARAN07/flyrank-ml-internship"
REPO_DIR = "flyrank-ml-internship"

if not os.path.isdir(REPO_DIR):
    subprocess.run(["git", "clone", REPO_URL], check=True)

os.chdir(REPO_DIR)

print("Current directory:", os.getcwd())
print("Data exists:", os.path.exists("data/raw/content_refresh_anonymized.csv"))
# Out:
# Current directory: /content/flyrank-ml-internship
# Data exists: True

# %%
import pandas as pd

df = pd.read_csv("data/raw/content_refresh_anonymized.csv")

print(f"Rows: {df.shape[0]}")
print(f"Columns: {df.shape[1]}")

print("\nTrend Direction Distribution:")
print(df["trend_direction"].value_counts())

print("\nAverage CTR:", round(df["ctr"].mean(), 4))
# Out:
# Rows: 30000
# Columns: 44
#
# Trend Direction Distribution:
# trend_direction
# down      16262
# stable     5962
# up         4388
# new        2236
# flat       1152
# Name: count, dtype: int64
#
# Average CTR: 0.5107

# %% [markdown]
# ## 4. Careful words: what I can and can't claim
#
# *Write what your work will be able to say (observed, directional, decision-support) — and what it never will (causal proof, 'predicting Google').*

# %% [markdown]
# ## Careful Claims
#
# This project can identify observed patterns in the available data and provide decision-support for prioritizing webpages that may benefit from optimization. The results are based on historical data and statistical relationships.
#
# However, this project cannot prove cause-and-effect relationships, predict Google's ranking algorithm, or guarantee that a webpage will recover after optimization. The model should support human decision-making rather than replace it.

# %% [markdown]
# ## Self-check
#
# Before you submit, confirm each line honestly:
#
# - [ ] Every section above is filled — markdown thinking AND the code that backs it
# - [ ] The notebook runs top to bottom with no errors (Runtime → Run all)
# - [ ] No client names, URLs, or private queries anywhere
# - [ ] My claims use careful words: observed, measured, directional, decision-support
# - [ ] Committed to my repo under `work/notebooks/` — then submit your repo URL on the card. Done.
